# %%
# from config import api_key
import pandas as pd
import numpy as np

# %%
# Data files
game_details_path = "games_details.csv"
games_path = "games.csv"
team_path = "teams.csv"

# Read the data files
game_details_data = pd.read_csv(game_details_path)
games_data = pd.read_csv(games_path)
teams_data = pd.read_csv(team_path)

# %%
game_details_data.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0  42000102  1610612764               WAS  Washington     203078
# 1  42000102  1610612764               WAS  Washington    1629060
# 2  42000102  1610612764               WAS  Washington     203458
# 3  42000102  1610612764               WAS  Washington     203526
# 4  42000102  1610612764               WAS  Washington     201566
#
#          PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  OREB  DREB  \
# 0       Bradley Beal              F     NaN  34:36  14.0  ...   0.0   4.0
# 1      Rui Hachimura              F     NaN  25:50   4.0  ...   2.0   5.0
# 2           Alex Len              C     NaN  12:11   3.0  ...   3.0   2.0
# 3          Raul Neto              G     NaN  19:19   2.0  ...   1.0   2.0
# 4  Russell Westbrook              G     NaN  29:07   2.0  ...   2.0   4.0
#
#    REB   AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  4.0   3.0  1.0  0.0  1.0  0.0  33.0       -22.0
# 1  7.0   1.0  0.0  0.0  3.0  4.0  11.0        -6.0
# 2  5.0   0.0  1.0  0.0  0.0  2.0   6.0       -11.0
# 3  3.0   1.0  0.0  0.0  0.0  2.0   4.0       -17.0
# 4  6.0  11.0  0.0  0.0  4.0  0.0  10.0       -16.0
#
# [5 rows x 28 columns]

# %%
games_data.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2021-05-26  42000102            Final    1610612755       1610612764
# 1    2021-05-26  42000132            Final    1610612752       1610612737
# 2    2021-05-26  42000142            Final    1610612762       1610612763
# 3    2021-05-25  42000112            Final    1610612751       1610612738
# 4    2021-05-25  42000152            Final    1610612756       1610612747
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2020    1610612755     120.0        0.557        0.684  ...      26.0
# 1    2020    1610612752     101.0        0.383        0.739  ...      15.0
# 2    2020    1610612762     141.0        0.544        0.774  ...      28.0
# 3    2020    1610612751     130.0        0.523        0.955  ...      31.0
# 4    2020    1610612756     102.0        0.465        0.933  ...      21.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      45.0    1610612764      95.0        0.402        0.633         0.091
# 1      54.0    1610612737      92.0        0.369        0.818         0.273
# 2      42.0    1610612763     129.0        0.541        0.763         0.348
# 3      46.0    1610612738     108.0        0.424        0.783         0.353
# 4      31.0    1610612747     109.0        0.450        0.871         0.303
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      22.0      40.0               1
# 1      17.0      41.0               1
# 2      20.0      33.0               1
# 3      23.0      43.0               1
# 4      24.0      39.0               0
#
# [5 rows x 21 columns]

# %%
teams_data.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# 0     Tony Ressler  Travis Schlenk   Lloyd Pierce      Erie Bayhawks
# 1    Wyc Grousbeck     Danny Ainge   Brad Stevens    Maine Red Claws
# 2       Tom Benson  Trajan Langdon   Alvin Gentry       No Affiliate
# 3  Jerry Reinsdorf      Gar Forman     Jim Boylen   Windy City Bulls
# 4       Mark Cuban   Donnie Nelson  Rick Carlisle      Texas Legends

# %%
# merging games details data with games data

merged = game_details_data.merge(games_data, on='GAME_ID')
merged
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0       42000102  1610612764               WAS  Washington     203078
# 1       42000102  1610612764               WAS  Washington    1629060
# 2       42000102  1610612764               WAS  Washington     203458
# 3       42000102  1610612764               WAS  Washington     203526
# 4       42000102  1610612764               WAS  Washington     201566
# ...          ...         ...               ...         ...        ...
# 617387  11200005  1610612743               DEN      Denver     202706
# 617388  11200005  1610612743               DEN      Denver     202702
# 617389  11200005  1610612743               DEN      Denver     201585
# 617390  11200005  1610612743               DEN      Denver     202389
# 617391  11200005  1610612743               DEN      Denver     201951
#
#               PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  AST_home  \
# 0            Bradley Beal              F     NaN  34:36  14.0  ...      26.0
# 1           Rui Hachimura              F     NaN  25:50   4.0  ...      26.0
# 2                Alex Len              C     NaN  12:11   3.0  ...      26.0
# 3               Raul Neto              G     NaN  19:19   2.0  ...      26.0
# 4       Russell Westbrook              G     NaN  29:07   2.0  ...      26.0
# ...                   ...            ...     ...    ...   ...  ...       ...
# 617387    Jordan Hamilton            NaN     NaN     19   4.0  ...      21.0
# 617388     Kenneth Faried            NaN     NaN     23   7.0  ...      21.0
# 617389       Kosta Koufos            NaN     NaN     15   3.0  ...      21.0
# 617390     Timofey Mozgov            NaN     NaN     19   1.0  ...      21.0
# 617391          Ty Lawson            NaN     NaN     27   3.0  ...      21.0
#
#         REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 0           45.0    1610612764      95.0        0.402        0.633
# 1           45.0    1610612764      95.0        0.402        0.633
# 2           45.0    1610612764      95.0        0.402        0.633
# 3           45.0    1610612764      95.0        0.402        0.633
# 4           45.0    1610612764      95.0        0.402        0.633
# ...          ...           ...       ...          ...          ...
# 617387      40.0    1610612743     106.0        0.532        0.615
# 617388      40.0    1610612743     106.0        0.532        0.615
# 617389      40.0    1610612743     106.0        0.532        0.615
# 617390      40.0    1610612743     106.0        0.532        0.615
# 617391      40.0    1610612743     106.0        0.532        0.615
#
#         FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0              0.091      22.0      40.0               1
# 1              0.091      22.0      40.0               1
# 2              0.091      22.0      40.0               1
# 3              0.091      22.0      40.0               1
# 4              0.091      22.0      40.0               1
# ...              ...       ...       ...             ...
# 617387         0.471      25.0      34.0               0
# 617388         0.471      25.0      34.0               0
# 617389         0.471      25.0      34.0               0
# 617390         0.471      25.0      34.0               0
# 617391         0.471      25.0      34.0               0
#
# [617392 rows x 48 columns]

# %%
# merging teams data to merged data

final_merged = merged.merge(teams_data, on='TEAM_ID')
final_merged
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0       42000102  1610612764               WAS  Washington     203078
# 1       42000102  1610612764               WAS  Washington    1629060
# 2       42000102  1610612764               WAS  Washington     203458
# 3       42000102  1610612764               WAS  Washington     203526
# 4       42000102  1610612764               WAS  Washington     201566
# ...          ...         ...               ...         ...        ...
# 617387  11200021  1610612758               SAC  Sacramento     201977
# 617388  11200021  1610612758               SAC  Sacramento     203080
# 617389  11200021  1610612758               SAC  Sacramento     203183
# 617390  11200021  1610612758               SAC  Sacramento     201936
# 617391  11200021  1610612758               SAC  Sacramento     203186
#
#               PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  \
# 0            Bradley Beal              F     NaN  34:36  14.0  ...
# 1           Rui Hachimura              F     NaN  25:50   4.0  ...
# 2                Alex Len              C     NaN  12:11   3.0  ...
# 3               Raul Neto              G     NaN  19:19   2.0  ...
# 4       Russell Westbrook              G     NaN  29:07   2.0  ...
# ...                   ...            ...     ...    ...   ...  ...
# 617387    Marcus Thornton            NaN     NaN     24   3.0  ...
# 617388    Thomas Robinson            NaN     NaN     29   4.0  ...
# 617389      Tony Mitchell            NaN     NaN      5   0.0  ...
# 617390       Tyreke Evans            NaN     NaN     24   4.0  ...
# 617391        Willie Reed            NaN     NaN      2   0.0  ...
#
#         ABBREVIATION  NICKNAME  YEARFOUNDED        CITY              ARENA  \
# 0                WAS   Wizards         1961  Washington  Capital One Arena
# 1                WAS   Wizards         1961  Washington  Capital One Arena
# 2                WAS   Wizards         1961  Washington  Capital One Arena
# 3                WAS   Wizards         1961  Washington  Capital One Arena
# 4                WAS   Wizards         1961  Washington  Capital One Arena
# ...              ...       ...          ...         ...                ...
# 617387           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617388           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617389           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617390           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617391           SAC     Kings         1948  Sacramento    Golden 1 Center
#
#         ARENACAPACITY           OWNER  GENERALMANAGER     HEADCOACH  \
# 0             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 1             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 2             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 3             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 4             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# ...               ...             ...             ...           ...
# 617387        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617388        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617389        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617390        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617391        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
#
#         DLEAGUEAFFILIATION
# 0       Capital City Go-Go
# 1       Capital City Go-Go
# 2       Capital City Go-Go
# 3       Capital City Go-Go
# 4       Capital City Go-Go
# ...                    ...
# 617387      Stockton Kings
# 617388      Stockton Kings
# 617389      Stockton Kings
# 617390      Stockton Kings
# 617391      Stockton Kings
#
# [617392 rows x 61 columns]

# %%
final_merged.to_csv("output.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-14-78c2f2b92345> in <module>
# ----> 1 final_merged.to_csv("output.csv", index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     246             )
#     247
# --> 248             self._save()
#     249
#     250     def _save(self) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     251         if self._need_to_save_header:
#     252             self._save_header()
# --> 253         self._save_body()
#     254
#     255     def _save_header(self) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_body(self)
#     289             if start_i >= end_i:
#     290                 break
# --> 291             self._save_chunk(start_i, end_i)
#     292
#     293     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     300
#     301         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 302         libwriters.write_csv_rows(data, ix, self.nlevels, self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# PermissionError: [Errno 13] Permission denied

# %%
#only focus on season 2018
mask = final_merged.SEASON != 2018
mask1 = final_merged[mask]
mask1
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0       42000102  1610612764               WAS  Washington     203078
# 1       42000102  1610612764               WAS  Washington    1629060
# 2       42000102  1610612764               WAS  Washington     203458
# 3       42000102  1610612764               WAS  Washington     203526
# 4       42000102  1610612764               WAS  Washington     201566
# ...          ...         ...               ...         ...        ...
# 617387  11200021  1610612758               SAC  Sacramento     201977
# 617388  11200021  1610612758               SAC  Sacramento     203080
# 617389  11200021  1610612758               SAC  Sacramento     203183
# 617390  11200021  1610612758               SAC  Sacramento     201936
# 617391  11200021  1610612758               SAC  Sacramento     203186
#
#               PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  \
# 0            Bradley Beal              F     NaN  34:36  14.0  ...
# 1           Rui Hachimura              F     NaN  25:50   4.0  ...
# 2                Alex Len              C     NaN  12:11   3.0  ...
# 3               Raul Neto              G     NaN  19:19   2.0  ...
# 4       Russell Westbrook              G     NaN  29:07   2.0  ...
# ...                   ...            ...     ...    ...   ...  ...
# 617387    Marcus Thornton            NaN     NaN     24   3.0  ...
# 617388    Thomas Robinson            NaN     NaN     29   4.0  ...
# 617389      Tony Mitchell            NaN     NaN      5   0.0  ...
# 617390       Tyreke Evans            NaN     NaN     24   4.0  ...
# 617391        Willie Reed            NaN     NaN      2   0.0  ...
#
#         ABBREVIATION  NICKNAME  YEARFOUNDED        CITY              ARENA  \
# 0                WAS   Wizards         1961  Washington  Capital One Arena
# 1                WAS   Wizards         1961  Washington  Capital One Arena
# 2                WAS   Wizards         1961  Washington  Capital One Arena
# 3                WAS   Wizards         1961  Washington  Capital One Arena
# 4                WAS   Wizards         1961  Washington  Capital One Arena
# ...              ...       ...          ...         ...                ...
# 617387           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617388           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617389           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617390           SAC     Kings         1948  Sacramento    Golden 1 Center
# 617391           SAC     Kings         1948  Sacramento    Golden 1 Center
#
#         ARENACAPACITY           OWNER  GENERALMANAGER     HEADCOACH  \
# 0             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 1             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 2             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 3             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# 4             20647.0     Ted Leonsis  Tommy Sheppard  Scott Brooks
# ...               ...             ...             ...           ...
# 617387        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617388        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617389        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617390        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
# 617391        17500.0  Vivek Ranadive     Vlade Divac   Luke Walton
#
#         DLEAGUEAFFILIATION
# 0       Capital City Go-Go
# 1       Capital City Go-Go
# 2       Capital City Go-Go
# 3       Capital City Go-Go
# 4       Capital City Go-Go
# ...                    ...
# 617387      Stockton Kings
# 617388      Stockton Kings
# 617389      Stockton Kings
# 617390      Stockton Kings
# 617391      Stockton Kings
#
# [582044 rows x 61 columns]

# %%
# excluding pre-season games
new_data = mask1[mask1["GAME_ID"] > 20000000]

new_data
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0       42000102  1610612764               WAS  Washington     203078
# 1       42000102  1610612764               WAS  Washington    1629060
# 2       42000102  1610612764               WAS  Washington     203458
# 3       42000102  1610612764               WAS  Washington     203526
# 4       42000102  1610612764               WAS  Washington     201566
# ...          ...         ...               ...         ...        ...
# 617294  21200007  1610612758               SAC  Sacramento     101128
# 617295  21200007  1610612758               SAC  Sacramento     101236
# 617296  21200007  1610612758               SAC  Sacramento     202690
# 617297  21200007  1610612758               SAC  Sacramento     202715
# 617298  21200007  1610612758               SAC  Sacramento       2566
#
#               PLAYER_NAME START_POSITION                 COMMENT    MIN   FGM  \
# 0            Bradley Beal              F                     NaN  34:36  14.0
# 1           Rui Hachimura              F                     NaN  25:50   4.0
# 2                Alex Len              C                     NaN  12:11   3.0
# 3               Raul Neto              G                     NaN  19:19   2.0
# 4       Russell Westbrook              G                     NaN  29:07   2.0
# ...                   ...            ...                     ...    ...   ...
# 617294   Francisco Garcia            NaN                     NaN   7:40   2.0
# 617295        Chuck Hayes            NaN                     NaN  17:43   1.0
# 617296    Jimmer Fredette            NaN                     NaN   0:06   0.0
# 617297    Tyler Honeycutt            NaN  DNP - Coach's Decision    NaN   NaN
# 617298      Travis Outlaw            NaN  DNP - Coach's Decision    NaN   NaN
#
#         ...  ABBREVIATION  NICKNAME  YEARFOUNDED        CITY  \
# 0       ...           WAS   Wizards         1961  Washington
# 1       ...           WAS   Wizards         1961  Washington
# 2       ...           WAS   Wizards         1961  Washington
# 3       ...           WAS   Wizards         1961  Washington
# 4       ...           WAS   Wizards         1961  Washington
# ...     ...           ...       ...          ...         ...
# 617294  ...           SAC     Kings         1948  Sacramento
# 617295  ...           SAC     Kings         1948  Sacramento
# 617296  ...           SAC     Kings         1948  Sacramento
# 617297  ...           SAC     Kings         1948  Sacramento
# 617298  ...           SAC     Kings         1948  Sacramento
#
#                     ARENA  ARENACAPACITY           OWNER  GENERALMANAGER  \
# 0       Capital One Arena        20647.0     Ted Leonsis  Tommy Sheppard
# 1       Capital One Arena        20647.0     Ted Leonsis  Tommy Sheppard
# 2       Capital One Arena        20647.0     Ted Leonsis  Tommy Sheppard
# 3       Capital One Arena        20647.0     Ted Leonsis  Tommy Sheppard
# 4       Capital One Arena        20647.0     Ted Leonsis  Tommy Sheppard
# ...                   ...            ...             ...             ...
# 617294    Golden 1 Center        17500.0  Vivek Ranadive     Vlade Divac
# 617295    Golden 1 Center        17500.0  Vivek Ranadive     Vlade Divac
# 617296    Golden 1 Center        17500.0  Vivek Ranadive     Vlade Divac
# 617297    Golden 1 Center        17500.0  Vivek Ranadive     Vlade Divac
# 617298    Golden 1 Center        17500.0  Vivek Ranadive     Vlade Divac
#
#            HEADCOACH  DLEAGUEAFFILIATION
# 0       Scott Brooks  Capital City Go-Go
# 1       Scott Brooks  Capital City Go-Go
# 2       Scott Brooks  Capital City Go-Go
# 3       Scott Brooks  Capital City Go-Go
# 4       Scott Brooks  Capital City Go-Go
# ...              ...                 ...
# 617294   Luke Walton      Stockton Kings
# 617295   Luke Walton      Stockton Kings
# 617296   Luke Walton      Stockton Kings
# 617297   Luke Walton      Stockton Kings
# 617298   Luke Walton      Stockton Kings
#
# [539792 rows x 61 columns]

# %%
# stadium has the most points/wins/ total games
